# %%
# !pip install numpy pandas scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\lokes\anaconda3\envs\project\lib\site-packages (2.2.5)
# Requirement already satisfied: pandas in c:\users\lokes\anaconda3\envs\project\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\lokes\anaconda3\envs\project\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\lokes\anaconda3\envs\project\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\lokes\anaconda3\envs\project\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\lokes\anaconda3\envs\project\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
df = pd.read_csv(r'C:\Users\lokes\Downloads\credit car fraud db\creditcard.csv')


# Display basic info
print(df.info())

# Check for missing values
print(df.isnull().sum())

# Display first few rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB
# None
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Assuming 'Class' is the target column (0 = legitimate, 1 = fraud)
X = df.drop(columns=['Class'])
y = df['Class']

# Standardizing numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# Check class distribution
print(y_train.value_counts(), "\n", y_test.value_counts())
# Out:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64
#  Class
# 0    56864
# 1       98
# Name: count, dtype: int64

# %%
# Initialize and train Naïve Bayes model
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

# Make predictions
y_pred = nb_model.predict(X_test)
y_pred_proba = nb_model.predict_proba(X_test)[:, 1]  # Probability of fraud

# %%
# Define costs
cost_false_positive = 1  # Cost of wrongly flagging a legit transaction
cost_false_negative = 10  # Cost of missing a fraud case

# Define threshold dynamically
threshold = cost_false_positive / (cost_false_positive + cost_false_negative)

# Apply decision rule
y_custom_pred = (y_pred_proba > threshold).astype(int)

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_custom_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Legit', 'Fraud'], yticklabels=['Legit', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(y_test, y_custom_pred))

# AUC-ROC Score
print("AUC-ROC Score:", roc_auc_score(y_test, y_pred_proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.06      0.86      0.11        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.92      0.55     56962
# weighted avg       1.00      0.98      0.99     56962
#
# AUC-ROC Score: 0.963247971529636

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Train model again
nb_model.fit(X_train_resampled, y_train_resampled)
# Out:
# C:\Users\lokes\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = nb_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9744039886239949
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.06      0.88      0.11        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.93      0.55     56962
# weighted avg       1.00      0.97      0.99     56962

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(nb_model, X_train, y_train, cv=5)
print("Cross-validation accuracy:", scores.mean())
# Out:
# Cross-validation accuracy: 0.9779806447365533

# %%
import joblib
joblib.dump(nb_model, "model.pkl")
# Out:
# ['model.pkl']

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Predict on test data
y_pred = nb_model.predict(X_test)

# Print accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Print classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Print confusion matrix
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9744039886239949
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.06      0.88      0.11        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.93      0.55     56962
# weighted avg       1.00      0.97      0.99     56962
#
#
# Confusion Matrix:
#  [[55418  1446]
#  [   12    86]]

# %%
train_accuracy = nb_model.score(X_train, y_train)
test_accuracy = nb_model.score(X_test, y_test)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9758300599091487
# Testing Accuracy: 0.9744039886239949

# %%
y_pred = nb_model.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.06      0.88      0.11        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.93      0.55     56962
# weighted avg       1.00      0.97      0.99     56962
